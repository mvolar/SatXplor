# %%
import os
import polars as pl
import utils.constants as constants
from utils.utils import read_gff_output, extract_subsequences
from Bio import SeqIO
import argparse

from logging_config import logger

def extract_array_flanks(df: pl.DataFrame,fasta_records: list,
                         flank_size: int =constants.FLANK_SIZE,flank_type: str="flanks") -> None:  


    grouped = df.group_by(["feature"])

    for group_key,group_df in grouped:
    
        #extract left flanks
        left_flanks = extract_subsequences(fasta_records, group_df,flanks="left",flank_size=flank_size)
        #extract right flanks
        right_flanks = extract_subsequences(fasta_records, group_df,flanks="right",flank_size=flank_size)
        #merge them together
        left_flanks.extend(right_flanks)
        
        #Write the subsequences to a new FASTA file
        output_file = constants.FLANKS_SAVE_ROOT + group_key[0] + "_"+ flank_type +".fasta"
        SeqIO.write(left_flanks, output_file, 'fasta')

def load_in_df_from_list_of_files(file_list: list,squish=False):
    
    df_list = []

    if squish:
        for i in file_list:
            name = i.split("/")[-1]
            name = name[:-4]
            name = name.split("_")[0:4]
            name = "_".join(name)
            tmp = pl.read_csv(i,dtypes={"index":int,
            "actual":float,
            "roll_mean":float},separator="\t")
            tmp = tmp.with_columns(
                name = pl.lit(name)
            )
            print(tmp)
            df_list.append(tmp)
    else: 
        for i in file_list:
            name = i.split("/")[-1]
            name = name[:-4]
            name = name.split("_")[0:3]
            name = "_".join(name)
            tmp = pl.read_csv(i,dtypes={"index":int,
            "actual":float,
            "roll_mean":float},separator="\t")
            tmp = tmp.with_columns(
                name = pl.lit(name)
            )
            df_list.append(tmp)
    return df_list

# %%
fasta_records = list(SeqIO.parse("../input.fasta", 'fasta'))
    

file_list = os.listdir("../results/kmer_analysis/" + "data")


file_list = ["../results/kmer_analysis/" + "data/" + string for string in file_list]

df_list = load_in_df_from_list_of_files(file_list=file_list,squish=constants.SQUISH)
# Out:
# shape: (1_461, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 14.0   ┆ 10.238095 ┆ Marev4contig105_MelSat49-103_240… │
# │ 1     ┆ 14.0   ┆ 10.095238 ┆ Marev4contig105_MelSat49-103_240… │
# │ 2     ┆ 14.0   ┆ 9.952381  ┆ Marev4contig105_MelSat49-103_240… │
# │ 3     ┆ 14.0   ┆ 9.809524  ┆ Marev4contig105_MelSat49-103_240… │
# │ 4     ┆ 14.0   ┆ 9.619048  ┆ Marev4contig105_MelSat49-103_240… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 1456  ┆ 0.0    ┆ 0.0       ┆ Marev4contig105_MelSat49-103_240… │
# │ 1457  ┆ 0.0    ┆ 0.0       ┆ Marev4contig105_MelSat49-103_240… │
# │ 1458  ┆ 0.0    ┆ 0.0       ┆ Marev4contig105_MelSat49-103_240… │
# │ 1459  ┆ 0.0    ┆ 0.0       ┆ Marev4contig105_MelSat49-103_240… │
# │ 1460  ┆ 0.0    ┆ 0.0       ┆ Marev4contig105_MelSat49-103_240… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (4_949, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 16.0   ┆ 11.761905 ┆ Marev4contig106_MelSat61-172_219… │
# │ 1     ┆ 16.0   ┆ 11.666667 ┆ Marev4contig106_MelSat61-172_219… │
# │ 2     ┆ 15.0   ┆ 11.571429 ┆ Marev4contig106_MelSat61-172_219… │
# │ 3     ┆ 15.0   ┆ 11.428571 ┆ Marev4contig106_MelSat61-172_219… │
# │ 4     ┆ 16.0   ┆ 11.380952 ┆ Marev4contig106_MelSat61-172_219… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 4944  ┆ 11.0   ┆ 9.190476  ┆ Marev4contig106_MelSat61-172_219… │
# │ 4945  ┆ 11.0   ┆ 9.0       ┆ Marev4contig106_MelSat61-172_219… │
# │ 4946  ┆ 11.0   ┆ 8.809524  ┆ Marev4contig106_MelSat61-172_219… │
# │ 4947  ┆ 12.0   ┆ 8.714286  ┆ Marev4contig106_MelSat61-172_219… │
# │ 4948  ┆ 13.0   ┆ 8.619048  ┆ Marev4contig106_MelSat61-172_219… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (4_949, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 16.0   ┆ 11.857143 ┆ Marev4contig109_MelSat22-186_395… │
# │ 1     ┆ 15.0   ┆ 11.952381 ┆ Marev4contig109_MelSat22-186_395… │
# │ 2     ┆ 14.0   ┆ 12.0      ┆ Marev4contig109_MelSat22-186_395… │
# │ 3     ┆ 14.0   ┆ 12.047619 ┆ Marev4contig109_MelSat22-186_395… │
# │ 4     ┆ 15.0   ┆ 12.095238 ┆ Marev4contig109_MelSat22-186_395… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 4944  ┆ 15.0   ┆ 10.0      ┆ Marev4contig109_MelSat22-186_395… │
# │ 4945  ┆ 16.0   ┆ 9.904762  ┆ Marev4contig109_MelSat22-186_395… │
# │ 4946  ┆ 16.0   ┆ 9.761905  ┆ Marev4contig109_MelSat22-186_395… │
# │ 4947  ┆ 15.0   ┆ 9.619048  ┆ Marev4contig109_MelSat22-186_395… │
# │ 4948  ┆ 15.0   ┆ 9.571429  ┆ Marev4contig109_MelSat22-186_395… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (4_949, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 14.0   ┆ 10.666667 ┆ Marev4contig109_MelSat48-90_1034… │
# │ 1     ┆ 14.0   ┆ 10.761905 ┆ Marev4contig109_MelSat48-90_1034… │
# │ 2     ┆ 14.0   ┆ 10.857143 ┆ Marev4contig109_MelSat48-90_1034… │
# │ 3     ┆ 15.0   ┆ 10.952381 ┆ Marev4contig109_MelSat48-90_1034… │
# │ 4     ┆ 15.0   ┆ 11.047619 ┆ Marev4contig109_MelSat48-90_1034… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 4944  ┆ 0.0    ┆ 0.0       ┆ Marev4contig109_MelSat48-90_1034… │
# │ 4945  ┆ 0.0    ┆ 0.0       ┆ Marev4contig109_MelSat48-90_1034… │
# │ 4946  ┆ 0.0    ┆ 0.0       ┆ Marev4contig109_MelSat48-90_1034… │
# │ 4947  ┆ 0.0    ┆ 0.0       ┆ Marev4contig109_MelSat48-90_1034… │
# │ 4948  ┆ 0.0    ┆ 0.0       ┆ Marev4contig109_MelSat48-90_1034… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (4_949, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 14.0   ┆ 9.333333  ┆ Marev4contig10_MelSat10-63_31773… │
# │ 1     ┆ 15.0   ┆ 9.47619   ┆ Marev4contig10_MelSat10-63_31773… │
# │ 2     ┆ 14.0   ┆ 9.619048  ┆ Marev4contig10_MelSat10-63_31773… │
# │ 3     ┆ 13.0   ┆ 9.761905  ┆ Marev4contig10_MelSat10-63_31773… │
# │ 4     ┆ 12.0   ┆ 9.904762  ┆ Marev4contig10_MelSat10-63_31773… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 4944  ┆ 13.0   ┆ 9.857143  ┆ Marev4contig10_MelSat10-63_31773… │
# │ 4945  ┆ 12.0   ┆ 9.857143  ┆ Marev4contig10_MelSat10-63_31773… │
# │ 4946  ┆ 11.0   ┆ 9.809524  ┆ Marev4contig10_MelSat10-63_31773… │
# │ 4947  ┆ 12.0   ┆ 9.761905  ┆ Marev4contig10_MelSat10-63_31773… │
# │ 4948  ┆ 13.0   ┆ 9.761905  ┆ Marev4contig10_MelSat10-63_31773… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (2_148, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 14.0   ┆ 10.904762 ┆ Marev4contig10_MelSat16-76_37007… │
# │ 1     ┆ 13.0   ┆ 11.047619 ┆ Marev4contig10_MelSat16-76_37007… │
# │ 2     ┆ 13.0   ┆ 11.142857 ┆ Marev4contig10_MelSat16-76_37007… │
# │ 3     ┆ 13.0   ┆ 11.238095 ┆ Marev4contig10_MelSat16-76_37007… │
# │ 4     ┆ 13.0   ┆ 11.285714 ┆ Marev4contig10_MelSat16-76_37007… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 2143  ┆ 18.0   ┆ 12.333333 ┆ Marev4contig10_MelSat16-76_37007… │
# │ 2144  ┆ 18.0   ┆ 12.142857 ┆ Marev4contig10_MelSat16-76_37007… │
# │ 2145  ┆ 18.0   ┆ 12.0      ┆ Marev4contig10_MelSat16-76_37007… │
# │ 2146  ┆ 18.0   ┆ 11.857143 ┆ Marev4contig10_MelSat16-76_37007… │
# │ 2147  ┆ 18.0   ┆ 11.761905 ┆ Marev4contig10_MelSat16-76_37007… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (1_550, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 17.0   ┆ 12.0      ┆ Marev4contig111_MelSat38-86_5498… │
# │ 1     ┆ 17.0   ┆ 11.904762 ┆ Marev4contig111_MelSat38-86_5498… │
# │ 2     ┆ 16.0   ┆ 11.857143 ┆ Marev4contig111_MelSat38-86_5498… │
# │ 3     ┆ 16.0   ┆ 11.857143 ┆ Marev4contig111_MelSat38-86_5498… │
# │ 4     ┆ 16.0   ┆ 11.904762 ┆ Marev4contig111_MelSat38-86_5498… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 1545  ┆ 14.0   ┆ 11.571429 ┆ Marev4contig111_MelSat38-86_5498… │
# │ 1546  ┆ 14.0   ┆ 11.52381  ┆ Marev4contig111_MelSat38-86_5498… │
# │ 1547  ┆ 15.0   ┆ 11.428571 ┆ Marev4contig111_MelSat38-86_5498… │
# │ 1548  ┆ 16.0   ┆ 11.285714 ┆ Marev4contig111_MelSat38-86_5498… │
# │ 1549  ┆ 16.0   ┆ 11.238095 ┆ Marev4contig111_MelSat38-86_5498… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (4_949, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 14.0   ┆ 10.619048 ┆ Marev4contig113_MelSat66-159_327… │
# │ 1     ┆ 13.0   ┆ 10.714286 ┆ Marev4contig113_MelSat66-159_327… │
# │ 2     ┆ 14.0   ┆ 10.761905 ┆ Marev4contig113_MelSat66-159_327… │
# │ 3     ┆ 13.0   ┆ 10.761905 ┆ Marev4contig113_MelSat66-159_327… │
# │ 4     ┆ 13.0   ┆ 10.714286 ┆ Marev4contig113_MelSat66-159_327… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 4944  ┆ 14.0   ┆ 9.619048  ┆ Marev4contig113_MelSat66-159_327… │
# │ 4945  ┆ 13.0   ┆ 9.666667  ┆ Marev4contig113_MelSat66-159_327… │
# │ 4946  ┆ 14.0   ┆ 9.761905  ┆ Marev4contig113_MelSat66-159_327… │
# │ 4947  ┆ 14.0   ┆ 9.904762  ┆ Marev4contig113_MelSat66-159_327… │
# │ 4948  ┆ 13.0   ┆ 10.0      ┆ Marev4contig113_MelSat66-159_327… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (4_949, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 15.0   ┆ 11.047619 ┆ Marev4contig115_MelSat40-184_866… │
# │ 1     ┆ 15.0   ┆ 11.095238 ┆ Marev4contig115_MelSat40-184_866… │
# │ 2     ┆ 15.0   ┆ 11.095238 ┆ Marev4contig115_MelSat40-184_866… │
# │ 3     ┆ 15.0   ┆ 11.190476 ┆ Marev4contig115_MelSat40-184_866… │
# │ 4     ┆ 14.0   ┆ 11.238095 ┆ Marev4contig115_MelSat40-184_866… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 4944  ┆ 15.0   ┆ 12.428571 ┆ Marev4contig115_MelSat40-184_866… │
# │ 4945  ┆ 15.0   ┆ 12.571429 ┆ Marev4contig115_MelSat40-184_866… │
# │ 4946  ┆ 15.0   ┆ 12.666667 ┆ Marev4contig115_MelSat40-184_866… │
# │ 4947  ┆ 14.0   ┆ 12.761905 ┆ Marev4contig115_MelSat40-184_866… │
# │ 4948  ┆ 15.0   ┆ 12.857143 ┆ Marev4contig115_MelSat40-184_866… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (4_949, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 17.0   ┆ 12.428571 ┆ Marev4contig121_MelSat09-94_6794… │
# │ 1     ┆ 17.0   ┆ 12.380952 ┆ Marev4contig121_MelSat09-94_6794… │
# │ 2     ┆ 16.0   ┆ 12.333333 ┆ Marev4contig121_MelSat09-94_6794… │
# │ 3     ┆ 16.0   ┆ 12.333333 ┆ Marev4contig121_MelSat09-94_6794… │
# │ 4     ┆ 15.0   ┆ 12.333333 ┆ Marev4contig121_MelSat09-94_6794… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 4944  ┆ 1.0    ┆ 0.619048  ┆ Marev4contig121_MelSat09-94_6794… │
# │ 4945  ┆ 1.0    ┆ 0.666667  ┆ Marev4contig121_MelSat09-94_6794… │
# │ 4946  ┆ 1.0    ┆ 0.761905  ┆ Marev4contig121_MelSat09-94_6794… │
# │ 4947  ┆ 1.0    ┆ 0.904762  ┆ Marev4contig121_MelSat09-94_6794… │
# │ 4948  ┆ 1.0    ┆ 1.047619  ┆ Marev4contig121_MelSat09-94_6794… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (1_883, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 14.0   ┆ 11.047619 ┆ Marev4contig122_MelSat79-78_8104… │
# │ 1     ┆ 14.0   ┆ 11.142857 ┆ Marev4contig122_MelSat79-78_8104… │
# │ 2     ┆ 14.0   ┆ 11.238095 ┆ Marev4contig122_MelSat79-78_8104… │
# │ 3     ┆ 14.0   ┆ 11.333333 ┆ Marev4contig122_MelSat79-78_8104… │
# │ 4     ┆ 14.0   ┆ 11.380952 ┆ Marev4contig122_MelSat79-78_8104… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 1878  ┆ 14.0   ┆ 10.666667 ┆ Marev4contig122_MelSat79-78_8104… │
# │ 1879  ┆ 15.0   ┆ 10.666667 ┆ Marev4contig122_MelSat79-78_8104… │
# │ 1880  ┆ 15.0   ┆ 10.571429 ┆ Marev4contig122_MelSat79-78_8104… │
# │ 1881  ┆ 15.0   ┆ 10.47619  ┆ Marev4contig122_MelSat79-78_8104… │
# │ 1882  ┆ 15.0   ┆ 10.333333 ┆ Marev4contig122_MelSat79-78_8104… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (4_949, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 13.0   ┆ 11.52381  ┆ Marev4contig127_MelSat45-146_595… │
# │ 1     ┆ 14.0   ┆ 11.571429 ┆ Marev4contig127_MelSat45-146_595… │
# │ 2     ┆ 15.0   ┆ 11.52381  ┆ Marev4contig127_MelSat45-146_595… │
# │ 3     ┆ 15.0   ┆ 11.52381  ┆ Marev4contig127_MelSat45-146_595… │
# │ 4     ┆ 15.0   ┆ 11.47619  ┆ Marev4contig127_MelSat45-146_595… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 4944  ┆ 0.0    ┆ 0.0       ┆ Marev4contig127_MelSat45-146_595… │
# │ 4945  ┆ 0.0    ┆ 0.0       ┆ Marev4contig127_MelSat45-146_595… │
# │ 4946  ┆ 0.0    ┆ 0.0       ┆ Marev4contig127_MelSat45-146_595… │
# │ 4947  ┆ 0.0    ┆ 0.0       ┆ Marev4contig127_MelSat45-146_595… │
# │ 4948  ┆ 0.0    ┆ 0.0       ┆ Marev4contig127_MelSat45-146_595… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (4_949, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 15.0   ┆ 11.285714 ┆ Marev4contig137_MelSat74-97_5664… │
# │ 1     ┆ 15.0   ┆ 11.285714 ┆ Marev4contig137_MelSat74-97_5664… │
# │ 2     ┆ 14.0   ┆ 11.285714 ┆ Marev4contig137_MelSat74-97_5664… │
# │ 3     ┆ 14.0   ┆ 11.285714 ┆ Marev4contig137_MelSat74-97_5664… │
# │ 4     ┆ 15.0   ┆ 11.285714 ┆ Marev4contig137_MelSat74-97_5664… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 4944  ┆ 14.0   ┆ 10.714286 ┆ Marev4contig137_MelSat74-97_5664… │
# │ 4945  ┆ 14.0   ┆ 10.666667 ┆ Marev4contig137_MelSat74-97_5664… │
# │ 4946  ┆ 14.0   ┆ 10.619048 ┆ Marev4contig137_MelSat74-97_5664… │
# │ 4947  ┆ 14.0   ┆ 10.52381  ┆ Marev4contig137_MelSat74-97_5664… │
# │ 4948  ┆ 14.0   ┆ 10.47619  ┆ Marev4contig137_MelSat74-97_5664… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (3_087, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 14.0   ┆ 11.428571 ┆ Marev4contig13_MelSat25-69_72585… │
# │ 1     ┆ 15.0   ┆ 11.380952 ┆ Marev4contig13_MelSat25-69_72585… │
# │ 2     ┆ 16.0   ┆ 11.333333 ┆ Marev4contig13_MelSat25-69_72585… │
# │ 3     ┆ 16.0   ┆ 11.285714 ┆ Marev4contig13_MelSat25-69_72585… │
# │ 4     ┆ 16.0   ┆ 11.285714 ┆ Marev4contig13_MelSat25-69_72585… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 3082  ┆ 15.0   ┆ 12.190476 ┆ Marev4contig13_MelSat25-69_72585… │
# │ 3083  ┆ 15.0   ┆ 12.238095 ┆ Marev4contig13_MelSat25-69_72585… │
# │ 3084  ┆ 14.0   ┆ 12.238095 ┆ Marev4contig13_MelSat25-69_72585… │
# │ 3085  ┆ 14.0   ┆ 12.238095 ┆ Marev4contig13_MelSat25-69_72585… │
# │ 3086  ┆ 14.0   ┆ 12.238095 ┆ Marev4contig13_MelSat25-69_72585… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (4_949, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 16.0   ┆ 9.809524  ┆ Marev4contig13_MelSat71-95_21773… │
# │ 1     ┆ 15.0   ┆ 9.619048  ┆ Marev4contig13_MelSat71-95_21773… │
# │ 2     ┆ 14.0   ┆ 9.47619   ┆ Marev4contig13_MelSat71-95_21773… │
# │ 3     ┆ 13.0   ┆ 9.285714  ┆ Marev4contig13_MelSat71-95_21773… │
# │ 4     ┆ 13.0   ┆ 9.0       ┆ Marev4contig13_MelSat71-95_21773… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 4944  ┆ 18.0   ┆ 12.904762 ┆ Marev4contig13_MelSat71-95_21773… │
# │ 4945  ┆ 18.0   ┆ 12.666667 ┆ Marev4contig13_MelSat71-95_21773… │
# │ 4946  ┆ 18.0   ┆ 12.428571 ┆ Marev4contig13_MelSat71-95_21773… │
# │ 4947  ┆ 18.0   ┆ 12.238095 ┆ Marev4contig13_MelSat71-95_21773… │
# │ 4948  ┆ 18.0   ┆ 12.095238 ┆ Marev4contig13_MelSat71-95_21773… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (3_994, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 19.0   ┆ 13.904762 ┆ Marev4contig146_MelSat53-85_2772… │
# │ 1     ┆ 19.0   ┆ 13.857143 ┆ Marev4contig146_MelSat53-85_2772… │
# │ 2     ┆ 18.0   ┆ 13.809524 ┆ Marev4contig146_MelSat53-85_2772… │
# │ 3     ┆ 19.0   ┆ 13.714286 ┆ Marev4contig146_MelSat53-85_2772… │
# │ 4     ┆ 19.0   ┆ 13.619048 ┆ Marev4contig146_MelSat53-85_2772… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 3989  ┆ 15.0   ┆ 10.047619 ┆ Marev4contig146_MelSat53-85_2772… │
# │ 3990  ┆ 15.0   ┆ 9.952381  ┆ Marev4contig146_MelSat53-85_2772… │
# │ 3991  ┆ 14.0   ┆ 9.904762  ┆ Marev4contig146_MelSat53-85_2772… │
# │ 3992  ┆ 15.0   ┆ 9.857143  ┆ Marev4contig146_MelSat53-85_2772… │
# │ 3993  ┆ 14.0   ┆ 9.809524  ┆ Marev4contig146_MelSat53-85_2772… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (4_949, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 13.0   ┆ 10.428571 ┆ Marev4contig14_MelSat63-60_16852… │
# │ 1     ┆ 13.0   ┆ 10.47619  ┆ Marev4contig14_MelSat63-60_16852… │
# │ 2     ┆ 13.0   ┆ 10.571429 ┆ Marev4contig14_MelSat63-60_16852… │
# │ 3     ┆ 13.0   ┆ 10.666667 ┆ Marev4contig14_MelSat63-60_16852… │
# │ 4     ┆ 14.0   ┆ 10.714286 ┆ Marev4contig14_MelSat63-60_16852… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 4944  ┆ 10.0   ┆ 1.47619   ┆ Marev4contig14_MelSat63-60_16852… │
# │ 4945  ┆ 9.0    ┆ 1.142857  ┆ Marev4contig14_MelSat63-60_16852… │
# │ 4946  ┆ 8.0    ┆ 0.857143  ┆ Marev4contig14_MelSat63-60_16852… │
# │ 4947  ┆ 8.0    ┆ 0.619048  ┆ Marev4contig14_MelSat63-60_16852… │
# │ 4948  ┆ 8.0    ┆ 0.428571  ┆ Marev4contig14_MelSat63-60_16852… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (4_036, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 17.0   ┆ 12.0      ┆ Marev4contig153_MelSat06-103_581… │
# │ 1     ┆ 17.0   ┆ 12.0      ┆ Marev4contig153_MelSat06-103_581… │
# │ 2     ┆ 17.0   ┆ 12.0      ┆ Marev4contig153_MelSat06-103_581… │
# │ 3     ┆ 17.0   ┆ 12.0      ┆ Marev4contig153_MelSat06-103_581… │
# │ 4     ┆ 16.0   ┆ 11.952381 ┆ Marev4contig153_MelSat06-103_581… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 4031  ┆ 17.0   ┆ 11.0      ┆ Marev4contig153_MelSat06-103_581… │
# │ 4032  ┆ 18.0   ┆ 10.904762 ┆ Marev4contig153_MelSat06-103_581… │
# │ 4033  ┆ 17.0   ┆ 10.857143 ┆ Marev4contig153_MelSat06-103_581… │
# │ 4034  ┆ 17.0   ┆ 10.761905 ┆ Marev4contig153_MelSat06-103_581… │
# │ 4035  ┆ 16.0   ┆ 10.714286 ┆ Marev4contig153_MelSat06-103_581… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (4_949, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 18.0   ┆ 13.285714 ┆ Marev4contig153_MelSat35-64_4537… │
# │ 1     ┆ 19.0   ┆ 13.238095 ┆ Marev4contig153_MelSat35-64_4537… │
# │ 2     ┆ 18.0   ┆ 13.190476 ┆ Marev4contig153_MelSat35-64_4537… │
# │ 3     ┆ 19.0   ┆ 13.142857 ┆ Marev4contig153_MelSat35-64_4537… │
# │ 4     ┆ 19.0   ┆ 13.095238 ┆ Marev4contig153_MelSat35-64_4537… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 4944  ┆ 17.0   ┆ 12.142857 ┆ Marev4contig153_MelSat35-64_4537… │
# │ 4945  ┆ 18.0   ┆ 12.142857 ┆ Marev4contig153_MelSat35-64_4537… │
# │ 4946  ┆ 17.0   ┆ 12.142857 ┆ Marev4contig153_MelSat35-64_4537… │
# │ 4947  ┆ 17.0   ┆ 12.095238 ┆ Marev4contig153_MelSat35-64_4537… │
# │ 4948  ┆ 17.0   ┆ 12.095238 ┆ Marev4contig153_MelSat35-64_4537… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (4_949, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 16.0   ┆ 10.904762 ┆ Marev4contig161_MelSat62-160_726… │
# │ 1     ┆ 15.0   ┆ 10.857143 ┆ Marev4contig161_MelSat62-160_726… │
# │ 2     ┆ 15.0   ┆ 10.809524 ┆ Marev4contig161_MelSat62-160_726… │
# │ 3     ┆ 15.0   ┆ 10.809524 ┆ Marev4contig161_MelSat62-160_726… │
# │ 4     ┆ 15.0   ┆ 10.857143 ┆ Marev4contig161_MelSat62-160_726… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 4944  ┆ 12.0   ┆ 11.095238 ┆ Marev4contig161_MelSat62-160_726… │
# │ 4945  ┆ 12.0   ┆ 11.095238 ┆ Marev4contig161_MelSat62-160_726… │
# │ 4946  ┆ 13.0   ┆ 11.142857 ┆ Marev4contig161_MelSat62-160_726… │
# │ 4947  ┆ 14.0   ┆ 11.095238 ┆ Marev4contig161_MelSat62-160_726… │
# │ 4948  ┆ 15.0   ┆ 11.095238 ┆ Marev4contig161_MelSat62-160_726… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (4_949, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 12.0   ┆ 9.52381   ┆ Marev4contig162_MelSat70-83_3627… │
# │ 1     ┆ 12.0   ┆ 9.52381   ┆ Marev4contig162_MelSat70-83_3627… │
# │ 2     ┆ 13.0   ┆ 9.47619   ┆ Marev4contig162_MelSat70-83_3627… │
# │ 3     ┆ 12.0   ┆ 9.52381   ┆ Marev4contig162_MelSat70-83_3627… │
# │ 4     ┆ 12.0   ┆ 9.619048  ┆ Marev4contig162_MelSat70-83_3627… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 4944  ┆ 9.0    ┆ 1.333333  ┆ Marev4contig162_MelSat70-83_3627… │
# │ 4945  ┆ 8.0    ┆ 1.095238  ┆ Marev4contig162_MelSat70-83_3627… │
# │ 4946  ┆ 7.0    ┆ 0.857143  ┆ Marev4contig162_MelSat70-83_3627… │
# │ 4947  ┆ 6.0    ┆ 0.666667  ┆ Marev4contig162_MelSat70-83_3627… │
# │ 4948  ┆ 5.0    ┆ 0.52381   ┆ Marev4contig162_MelSat70-83_3627… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (4_949, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 16.0   ┆ 11.714286 ┆ Marev4contig168_MelSat52-97_3786… │
# │ 1     ┆ 15.0   ┆ 11.714286 ┆ Marev4contig168_MelSat52-97_3786… │
# │ 2     ┆ 15.0   ┆ 11.714286 ┆ Marev4contig168_MelSat52-97_3786… │
# │ 3     ┆ 15.0   ┆ 11.714286 ┆ Marev4contig168_MelSat52-97_3786… │
# │ 4     ┆ 15.0   ┆ 11.714286 ┆ Marev4contig168_MelSat52-97_3786… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 4944  ┆ 0.0    ┆ 0.0       ┆ Marev4contig168_MelSat52-97_3786… │
# │ 4945  ┆ 0.0    ┆ 0.0       ┆ Marev4contig168_MelSat52-97_3786… │
# │ 4946  ┆ 0.0    ┆ 0.0       ┆ Marev4contig168_MelSat52-97_3786… │
# │ 4947  ┆ 0.0    ┆ 0.0       ┆ Marev4contig168_MelSat52-97_3786… │
# │ 4948  ┆ 0.0    ┆ 0.0       ┆ Marev4contig168_MelSat52-97_3786… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (4_949, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 14.0   ┆ 9.571429  ┆ Marev4contig172_MelSat55-69_1859… │
# │ 1     ┆ 14.0   ┆ 9.619048  ┆ Marev4contig172_MelSat55-69_1859… │
# │ 2     ┆ 14.0   ┆ 9.666667  ┆ Marev4contig172_MelSat55-69_1859… │
# │ 3     ┆ 14.0   ┆ 9.761905  ┆ Marev4contig172_MelSat55-69_1859… │
# │ 4     ┆ 13.0   ┆ 9.857143  ┆ Marev4contig172_MelSat55-69_1859… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 4944  ┆ 0.0    ┆ 0.047619  ┆ Marev4contig172_MelSat55-69_1859… │
# │ 4945  ┆ 0.0    ┆ 0.095238  ┆ Marev4contig172_MelSat55-69_1859… │
# │ 4946  ┆ 0.0    ┆ 0.190476  ┆ Marev4contig172_MelSat55-69_1859… │
# │ 4947  ┆ 0.0    ┆ 0.333333  ┆ Marev4contig172_MelSat55-69_1859… │
# │ 4948  ┆ 0.0    ┆ 0.52381   ┆ Marev4contig172_MelSat55-69_1859… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (4_949, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 14.0   ┆ 10.047619 ┆ Marev4contig174_MelSat46-84_1853… │
# │ 1     ┆ 14.0   ┆ 10.095238 ┆ Marev4contig174_MelSat46-84_1853… │
# │ 2     ┆ 14.0   ┆ 10.142857 ┆ Marev4contig174_MelSat46-84_1853… │
# │ 3     ┆ 13.0   ┆ 10.238095 ┆ Marev4contig174_MelSat46-84_1853… │
# │ 4     ┆ 14.0   ┆ 10.333333 ┆ Marev4contig174_MelSat46-84_1853… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 4944  ┆ 12.0   ┆ 10.190476 ┆ Marev4contig174_MelSat46-84_1853… │
# │ 4945  ┆ 12.0   ┆ 10.238095 ┆ Marev4contig174_MelSat46-84_1853… │
# │ 4946  ┆ 11.0   ┆ 10.238095 ┆ Marev4contig174_MelSat46-84_1853… │
# │ 4947  ┆ 12.0   ┆ 10.285714 ┆ Marev4contig174_MelSat46-84_1853… │
# │ 4948  ┆ 12.0   ┆ 10.285714 ┆ Marev4contig174_MelSat46-84_1853… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (4_949, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 16.0   ┆ 12.142857 ┆ Marev4contig175_MelSat51-80_2660… │
# │ 1     ┆ 15.0   ┆ 12.095238 ┆ Marev4contig175_MelSat51-80_2660… │
# │ 2     ┆ 16.0   ┆ 12.095238 ┆ Marev4contig175_MelSat51-80_2660… │
# │ 3     ┆ 17.0   ┆ 12.095238 ┆ Marev4contig175_MelSat51-80_2660… │
# │ 4     ┆ 17.0   ┆ 12.095238 ┆ Marev4contig175_MelSat51-80_2660… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 4944  ┆ 16.0   ┆ 12.571429 ┆ Marev4contig175_MelSat51-80_2660… │
# │ 4945  ┆ 16.0   ┆ 12.619048 ┆ Marev4contig175_MelSat51-80_2660… │
# │ 4946  ┆ 15.0   ┆ 12.714286 ┆ Marev4contig175_MelSat51-80_2660… │
# │ 4947  ┆ 15.0   ┆ 12.761905 ┆ Marev4contig175_MelSat51-80_2660… │
# │ 4948  ┆ 15.0   ┆ 12.857143 ┆ Marev4contig175_MelSat51-80_2660… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (2_077, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 14.0   ┆ 9.380952  ┆ Marev4contig191_MelSat03-87_3985… │
# │ 1     ┆ 14.0   ┆ 9.428571  ┆ Marev4contig191_MelSat03-87_3985… │
# │ 2     ┆ 13.0   ┆ 9.47619   ┆ Marev4contig191_MelSat03-87_3985… │
# │ 3     ┆ 12.0   ┆ 9.52381   ┆ Marev4contig191_MelSat03-87_3985… │
# │ 4     ┆ 12.0   ┆ 9.571429  ┆ Marev4contig191_MelSat03-87_3985… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 2072  ┆ 13.0   ┆ 10.190476 ┆ Marev4contig191_MelSat03-87_3985… │
# │ 2073  ┆ 12.0   ┆ 10.238095 ┆ Marev4contig191_MelSat03-87_3985… │
# │ 2074  ┆ 12.0   ┆ 10.285714 ┆ Marev4contig191_MelSat03-87_3985… │
# │ 2075  ┆ 12.0   ┆ 10.238095 ┆ Marev4contig191_MelSat03-87_3985… │
# │ 2076  ┆ 12.0   ┆ 10.190476 ┆ Marev4contig191_MelSat03-87_3985… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (4_949, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 13.0   ┆ 9.333333  ┆ Marev4contig19_MelSat04-89_31058… │
# │ 1     ┆ 13.0   ┆ 9.333333  ┆ Marev4contig19_MelSat04-89_31058… │
# │ 2     ┆ 13.0   ┆ 9.380952  ┆ Marev4contig19_MelSat04-89_31058… │
# │ 3     ┆ 13.0   ┆ 9.47619   ┆ Marev4contig19_MelSat04-89_31058… │
# │ 4     ┆ 13.0   ┆ 9.52381   ┆ Marev4contig19_MelSat04-89_31058… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 4944  ┆ 0.0    ┆ 3.809524  ┆ Marev4contig19_MelSat04-89_31058… │
# │ 4945  ┆ 0.0    ┆ 4.095238  ┆ Marev4contig19_MelSat04-89_31058… │
# │ 4946  ┆ 0.0    ┆ 4.380952  ┆ Marev4contig19_MelSat04-89_31058… │
# │ 4947  ┆ 0.0    ┆ 4.619048  ┆ Marev4contig19_MelSat04-89_31058… │
# │ 4948  ┆ 1.0    ┆ 4.761905  ┆ Marev4contig19_MelSat04-89_31058… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (3_552, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 11.0   ┆ 7.952381  ┆ Marev4contig203_MelSat83-173_359… │
# │ 1     ┆ 11.0   ┆ 7.714286  ┆ Marev4contig203_MelSat83-173_359… │
# │ 2     ┆ 12.0   ┆ 7.52381   ┆ Marev4contig203_MelSat83-173_359… │
# │ 3     ┆ 13.0   ┆ 7.285714  ┆ Marev4contig203_MelSat83-173_359… │
# │ 4     ┆ 13.0   ┆ 7.142857  ┆ Marev4contig203_MelSat83-173_359… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 3547  ┆ 8.0    ┆ 7.047619  ┆ Marev4contig203_MelSat83-173_359… │
# │ 3548  ┆ 8.0    ┆ 7.238095  ┆ Marev4contig203_MelSat83-173_359… │
# │ 3549  ┆ 8.0    ┆ 7.333333  ┆ Marev4contig203_MelSat83-173_359… │
# │ 3550  ┆ 7.0    ┆ 7.428571  ┆ Marev4contig203_MelSat83-173_359… │
# │ 3551  ┆ 7.0    ┆ 7.52381   ┆ Marev4contig203_MelSat83-173_359… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (4_949, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 0.0    ┆ 2.428571  ┆ Marev4contig205_MelSat01-295_584… │
# │ 1     ┆ 0.0    ┆ 2.571429  ┆ Marev4contig205_MelSat01-295_584… │
# │ 2     ┆ 0.0    ┆ 2.666667  ┆ Marev4contig205_MelSat01-295_584… │
# │ 3     ┆ 0.0    ┆ 2.714286  ┆ Marev4contig205_MelSat01-295_584… │
# │ 4     ┆ 0.0    ┆ 2.666667  ┆ Marev4contig205_MelSat01-295_584… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 4944  ┆ 0.0    ┆ 0.0       ┆ Marev4contig205_MelSat01-295_584… │
# │ 4945  ┆ 0.0    ┆ 0.0       ┆ Marev4contig205_MelSat01-295_584… │
# │ 4946  ┆ 0.0    ┆ 0.0       ┆ Marev4contig205_MelSat01-295_584… │
# │ 4947  ┆ 0.0    ┆ 0.0       ┆ Marev4contig205_MelSat01-295_584… │
# │ 4948  ┆ 0.0    ┆ 0.0       ┆ Marev4contig205_MelSat01-295_584… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (2_270, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 15.0   ┆ 11.380952 ┆ Marev4contig210_MelSat26-63_9954… │
# │ 1     ┆ 15.0   ┆ 11.285714 ┆ Marev4contig210_MelSat26-63_9954… │
# │ 2     ┆ 15.0   ┆ 11.238095 ┆ Marev4contig210_MelSat26-63_9954… │
# │ 3     ┆ 14.0   ┆ 11.190476 ┆ Marev4contig210_MelSat26-63_9954… │
# │ 4     ┆ 15.0   ┆ 11.142857 ┆ Marev4contig210_MelSat26-63_9954… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 2265  ┆ 14.0   ┆ 11.952381 ┆ Marev4contig210_MelSat26-63_9954… │
# │ 2266  ┆ 15.0   ┆ 11.904762 ┆ Marev4contig210_MelSat26-63_9954… │
# │ 2267  ┆ 15.0   ┆ 11.857143 ┆ Marev4contig210_MelSat26-63_9954… │
# │ 2268  ┆ 15.0   ┆ 11.809524 ┆ Marev4contig210_MelSat26-63_9954… │
# │ 2269  ┆ 16.0   ┆ 11.714286 ┆ Marev4contig210_MelSat26-63_9954… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (4_949, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 15.0   ┆ 13.619048 ┆ Marev4contig210_MelSat64-14_1788… │
# │ 1     ┆ 16.0   ┆ 13.571429 ┆ Marev4contig210_MelSat64-14_1788… │
# │ 2     ┆ 15.0   ┆ 13.47619  ┆ Marev4contig210_MelSat64-14_1788… │
# │ 3     ┆ 16.0   ┆ 13.285714 ┆ Marev4contig210_MelSat64-14_1788… │
# │ 4     ┆ 16.0   ┆ 13.142857 ┆ Marev4contig210_MelSat64-14_1788… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 4944  ┆ 13.0   ┆ 9.238095  ┆ Marev4contig210_MelSat64-14_1788… │
# │ 4945  ┆ 13.0   ┆ 9.285714  ┆ Marev4contig210_MelSat64-14_1788… │
# │ 4946  ┆ 13.0   ┆ 9.285714  ┆ Marev4contig210_MelSat64-14_1788… │
# │ 4947  ┆ 13.0   ┆ 9.285714  ┆ Marev4contig210_MelSat64-14_1788… │
# │ 4948  ┆ 12.0   ┆ 9.285714  ┆ Marev4contig210_MelSat64-14_1788… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (4_949, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 14.0   ┆ 11.571429 ┆ Marev4contig217_MelSat80-57_1508… │
# │ 1     ┆ 14.0   ┆ 11.619048 ┆ Marev4contig217_MelSat80-57_1508… │
# │ 2     ┆ 15.0   ┆ 11.666667 ┆ Marev4contig217_MelSat80-57_1508… │
# │ 3     ┆ 14.0   ┆ 11.714286 ┆ Marev4contig217_MelSat80-57_1508… │
# │ 4     ┆ 14.0   ┆ 11.714286 ┆ Marev4contig217_MelSat80-57_1508… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 4944  ┆ 8.0    ┆ 1.857143  ┆ Marev4contig217_MelSat80-57_1508… │
# │ 4945  ┆ 7.0    ┆ 1.666667  ┆ Marev4contig217_MelSat80-57_1508… │
# │ 4946  ┆ 6.0    ┆ 1.47619   ┆ Marev4contig217_MelSat80-57_1508… │
# │ 4947  ┆ 5.0    ┆ 1.285714  ┆ Marev4contig217_MelSat80-57_1508… │
# │ 4948  ┆ 4.0    ┆ 1.095238  ┆ Marev4contig217_MelSat80-57_1508… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (1_578, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 12.0   ┆ 11.904762 ┆ Marev4contig221_MelSat37-157_852… │
# │ 1     ┆ 12.0   ┆ 12.095238 ┆ Marev4contig221_MelSat37-157_852… │
# │ 2     ┆ 12.0   ┆ 12.333333 ┆ Marev4contig221_MelSat37-157_852… │
# │ 3     ┆ 13.0   ┆ 12.52381  ┆ Marev4contig221_MelSat37-157_852… │
# │ 4     ┆ 13.0   ┆ 12.666667 ┆ Marev4contig221_MelSat37-157_852… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 1573  ┆ 13.0   ┆ 9.095238  ┆ Marev4contig221_MelSat37-157_852… │
# │ 1574  ┆ 13.0   ┆ 9.142857  ┆ Marev4contig221_MelSat37-157_852… │
# │ 1575  ┆ 13.0   ┆ 9.095238  ┆ Marev4contig221_MelSat37-157_852… │
# │ 1576  ┆ 13.0   ┆ 9.095238  ┆ Marev4contig221_MelSat37-157_852… │
# │ 1577  ┆ 12.0   ┆ 9.095238  ┆ Marev4contig221_MelSat37-157_852… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (4_949, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 15.0   ┆ 10.190476 ┆ Marev4contig227_MelSat65-170_376… │
# │ 1     ┆ 14.0   ┆ 10.238095 ┆ Marev4contig227_MelSat65-170_376… │
# │ 2     ┆ 14.0   ┆ 10.238095 ┆ Marev4contig227_MelSat65-170_376… │
# │ 3     ┆ 13.0   ┆ 10.190476 ┆ Marev4contig227_MelSat65-170_376… │
# │ 4     ┆ 13.0   ┆ 10.238095 ┆ Marev4contig227_MelSat65-170_376… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 4944  ┆ 13.0   ┆ 9.761905  ┆ Marev4contig227_MelSat65-170_376… │
# │ 4945  ┆ 14.0   ┆ 9.904762  ┆ Marev4contig227_MelSat65-170_376… │
# │ 4946  ┆ 13.0   ┆ 10.047619 ┆ Marev4contig227_MelSat65-170_376… │
# │ 4947  ┆ 12.0   ┆ 10.095238 ┆ Marev4contig227_MelSat65-170_376… │
# │ 4948  ┆ 13.0   ┆ 10.047619 ┆ Marev4contig227_MelSat65-170_376… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (4_949, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 15.0   ┆ 11.285714 ┆ Marev4contig24_MelSat78-97_23136… │
# │ 1     ┆ 15.0   ┆ 11.380952 ┆ Marev4contig24_MelSat78-97_23136… │
# │ 2     ┆ 15.0   ┆ 11.52381  ┆ Marev4contig24_MelSat78-97_23136… │
# │ 3     ┆ 15.0   ┆ 11.666667 ┆ Marev4contig24_MelSat78-97_23136… │
# │ 4     ┆ 15.0   ┆ 11.714286 ┆ Marev4contig24_MelSat78-97_23136… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 4944  ┆ 14.0   ┆ 11.190476 ┆ Marev4contig24_MelSat78-97_23136… │
# │ 4945  ┆ 14.0   ┆ 11.190476 ┆ Marev4contig24_MelSat78-97_23136… │
# │ 4946  ┆ 14.0   ┆ 11.238095 ┆ Marev4contig24_MelSat78-97_23136… │
# │ 4947  ┆ 14.0   ┆ 11.285714 ┆ Marev4contig24_MelSat78-97_23136… │
# │ 4948  ┆ 15.0   ┆ 11.285714 ┆ Marev4contig24_MelSat78-97_23136… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (4_949, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 14.0   ┆ 10.333333 ┆ Marev4contig2_MelSat47-240_38555… │
# │ 1     ┆ 14.0   ┆ 10.333333 ┆ Marev4contig2_MelSat47-240_38555… │
# │ 2     ┆ 14.0   ┆ 10.333333 ┆ Marev4contig2_MelSat47-240_38555… │
# │ 3     ┆ 15.0   ┆ 10.333333 ┆ Marev4contig2_MelSat47-240_38555… │
# │ 4     ┆ 15.0   ┆ 10.333333 ┆ Marev4contig2_MelSat47-240_38555… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 4944  ┆ 16.0   ┆ 10.714286 ┆ Marev4contig2_MelSat47-240_38555… │
# │ 4945  ┆ 15.0   ┆ 10.809524 ┆ Marev4contig2_MelSat47-240_38555… │
# │ 4946  ┆ 15.0   ┆ 10.952381 ┆ Marev4contig2_MelSat47-240_38555… │
# │ 4947  ┆ 15.0   ┆ 11.095238 ┆ Marev4contig2_MelSat47-240_38555… │
# │ 4948  ┆ 14.0   ┆ 11.142857 ┆ Marev4contig2_MelSat47-240_38555… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (4_949, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 13.0   ┆ 10.714286 ┆ Marev4contig31_MelSat43-65_27282… │
# │ 1     ┆ 13.0   ┆ 10.857143 ┆ Marev4contig31_MelSat43-65_27282… │
# │ 2     ┆ 13.0   ┆ 10.952381 ┆ Marev4contig31_MelSat43-65_27282… │
# │ 3     ┆ 13.0   ┆ 11.0      ┆ Marev4contig31_MelSat43-65_27282… │
# │ 4     ┆ 13.0   ┆ 11.095238 ┆ Marev4contig31_MelSat43-65_27282… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 4944  ┆ 0.0    ┆ 0.095238  ┆ Marev4contig31_MelSat43-65_27282… │
# │ 4945  ┆ 0.0    ┆ 0.095238  ┆ Marev4contig31_MelSat43-65_27282… │
# │ 4946  ┆ 0.0    ┆ 0.142857  ┆ Marev4contig31_MelSat43-65_27282… │
# │ 4947  ┆ 0.0    ┆ 0.190476  ┆ Marev4contig31_MelSat43-65_27282… │
# │ 4948  ┆ 0.0    ┆ 0.285714  ┆ Marev4contig31_MelSat43-65_27282… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (4_949, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 12.0   ┆ 11.619048 ┆ Marev4contig3_MelSat12-74_416250… │
# │ 1     ┆ 13.0   ┆ 11.619048 ┆ Marev4contig3_MelSat12-74_416250… │
# │ 2     ┆ 13.0   ┆ 11.571429 ┆ Marev4contig3_MelSat12-74_416250… │
# │ 3     ┆ 14.0   ┆ 11.47619  ┆ Marev4contig3_MelSat12-74_416250… │
# │ 4     ┆ 15.0   ┆ 11.47619  ┆ Marev4contig3_MelSat12-74_416250… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 4944  ┆ 15.0   ┆ 12.095238 ┆ Marev4contig3_MelSat12-74_416250… │
# │ 4945  ┆ 16.0   ┆ 12.0      ┆ Marev4contig3_MelSat12-74_416250… │
# │ 4946  ┆ 16.0   ┆ 11.857143 ┆ Marev4contig3_MelSat12-74_416250… │
# │ 4947  ┆ 16.0   ┆ 11.714286 ┆ Marev4contig3_MelSat12-74_416250… │
# │ 4948  ┆ 16.0   ┆ 11.619048 ┆ Marev4contig3_MelSat12-74_416250… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (4_949, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 14.0   ┆ 12.428571 ┆ Marev4contig3_MelSat21-55_382124… │
# │ 1     ┆ 15.0   ┆ 12.428571 ┆ Marev4contig3_MelSat21-55_382124… │
# │ 2     ┆ 16.0   ┆ 12.47619  ┆ Marev4contig3_MelSat21-55_382124… │
# │ 3     ┆ 17.0   ┆ 12.52381  ┆ Marev4contig3_MelSat21-55_382124… │
# │ 4     ┆ 16.0   ┆ 12.571429 ┆ Marev4contig3_MelSat21-55_382124… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 4944  ┆ 16.0   ┆ 11.904762 ┆ Marev4contig3_MelSat21-55_382124… │
# │ 4945  ┆ 16.0   ┆ 11.857143 ┆ Marev4contig3_MelSat21-55_382124… │
# │ 4946  ┆ 16.0   ┆ 11.809524 ┆ Marev4contig3_MelSat21-55_382124… │
# │ 4947  ┆ 16.0   ┆ 11.761905 ┆ Marev4contig3_MelSat21-55_382124… │
# │ 4948  ┆ 16.0   ┆ 11.761905 ┆ Marev4contig3_MelSat21-55_382124… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (4_949, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 17.0   ┆ 13.095238 ┆ Marev4contig3_MelSat31-57_319552… │
# │ 1     ┆ 17.0   ┆ 13.0      ┆ Marev4contig3_MelSat31-57_319552… │
# │ 2     ┆ 16.0   ┆ 12.952381 ┆ Marev4contig3_MelSat31-57_319552… │
# │ 3     ┆ 17.0   ┆ 12.857143 ┆ Marev4contig3_MelSat31-57_319552… │
# │ 4     ┆ 17.0   ┆ 12.809524 ┆ Marev4contig3_MelSat31-57_319552… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 4944  ┆ 17.0   ┆ 12.095238 ┆ Marev4contig3_MelSat31-57_319552… │
# │ 4945  ┆ 16.0   ┆ 12.047619 ┆ Marev4contig3_MelSat31-57_319552… │
# │ 4946  ┆ 15.0   ┆ 12.0      ┆ Marev4contig3_MelSat31-57_319552… │
# │ 4947  ┆ 16.0   ┆ 12.0      ┆ Marev4contig3_MelSat31-57_319552… │
# │ 4948  ┆ 16.0   ┆ 12.0      ┆ Marev4contig3_MelSat31-57_319552… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (3_113, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 16.0   ┆ 12.857143 ┆ Marev4contig3_MelSat33-57_346765… │
# │ 1     ┆ 17.0   ┆ 12.857143 ┆ Marev4contig3_MelSat33-57_346765… │
# │ 2     ┆ 17.0   ┆ 12.809524 ┆ Marev4contig3_MelSat33-57_346765… │
# │ 3     ┆ 16.0   ┆ 12.714286 ┆ Marev4contig3_MelSat33-57_346765… │
# │ 4     ┆ 16.0   ┆ 12.571429 ┆ Marev4contig3_MelSat33-57_346765… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 3108  ┆ 16.0   ┆ 12.380952 ┆ Marev4contig3_MelSat33-57_346765… │
# │ 3109  ┆ 16.0   ┆ 12.380952 ┆ Marev4contig3_MelSat33-57_346765… │
# │ 3110  ┆ 16.0   ┆ 12.333333 ┆ Marev4contig3_MelSat33-57_346765… │
# │ 3111  ┆ 17.0   ┆ 12.380952 ┆ Marev4contig3_MelSat33-57_346765… │
# │ 3112  ┆ 18.0   ┆ 12.380952 ┆ Marev4contig3_MelSat33-57_346765… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (4_949, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 16.0   ┆ 13.428571 ┆ Marev4contig3_MelSat39-98_374758… │
# │ 1     ┆ 16.0   ┆ 13.380952 ┆ Marev4contig3_MelSat39-98_374758… │
# │ 2     ┆ 16.0   ┆ 13.285714 ┆ Marev4contig3_MelSat39-98_374758… │
# ...
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 18.0   ┆ 13.380952 ┆ Marev4contig47_MelSat56-62_12664… │
# │ 1     ┆ 18.0   ┆ 13.333333 ┆ Marev4contig47_MelSat56-62_12664… │
# │ 2     ┆ 17.0   ┆ 13.333333 ┆ Marev4contig47_MelSat56-62_12664… │
# │ 3     ┆ 18.0   ┆ 13.333333 ┆ Marev4contig47_MelSat56-62_12664… │
# │ 4     ┆ 19.0   ┆ 13.333333 ┆ Marev4contig47_MelSat56-62_12664… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 4944  ┆ 16.0   ┆ 12.0      ┆ Marev4contig47_MelSat56-62_12664… │
# │ 4945  ┆ 16.0   ┆ 11.952381 ┆ Marev4contig47_MelSat56-62_12664… │
# │ 4946  ┆ 17.0   ┆ 11.809524 ┆ Marev4contig47_MelSat56-62_12664… │
# │ 4947  ┆ 16.0   ┆ 11.714286 ┆ Marev4contig47_MelSat56-62_12664… │
# │ 4948  ┆ 16.0   ┆ 11.666667 ┆ Marev4contig47_MelSat56-62_12664… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (4_949, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 14.0   ┆ 10.904762 ┆ Marev4contig60_MelSat67-85_16546… │
# │ 1     ┆ 13.0   ┆ 10.904762 ┆ Marev4contig60_MelSat67-85_16546… │
# │ 2     ┆ 14.0   ┆ 10.904762 ┆ Marev4contig60_MelSat67-85_16546… │
# │ 3     ┆ 14.0   ┆ 10.857143 ┆ Marev4contig60_MelSat67-85_16546… │
# │ 4     ┆ 15.0   ┆ 10.904762 ┆ Marev4contig60_MelSat67-85_16546… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 4944  ┆ 19.0   ┆ 12.952381 ┆ Marev4contig60_MelSat67-85_16546… │
# │ 4945  ┆ 18.0   ┆ 12.809524 ┆ Marev4contig60_MelSat67-85_16546… │
# │ 4946  ┆ 18.0   ┆ 12.761905 ┆ Marev4contig60_MelSat67-85_16546… │
# │ 4947  ┆ 18.0   ┆ 12.666667 ┆ Marev4contig60_MelSat67-85_16546… │
# │ 4948  ┆ 18.0   ┆ 12.619048 ┆ Marev4contig60_MelSat67-85_16546… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (4_949, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 13.0   ┆ 9.952381  ┆ Marev4contig75_MelSat50-109_8478… │
# │ 1     ┆ 12.0   ┆ 10.0      ┆ Marev4contig75_MelSat50-109_8478… │
# │ 2     ┆ 12.0   ┆ 10.0      ┆ Marev4contig75_MelSat50-109_8478… │
# │ 3     ┆ 13.0   ┆ 10.0      ┆ Marev4contig75_MelSat50-109_8478… │
# │ 4     ┆ 13.0   ┆ 10.047619 ┆ Marev4contig75_MelSat50-109_8478… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 4944  ┆ 14.0   ┆ 11.952381 ┆ Marev4contig75_MelSat50-109_8478… │
# │ 4945  ┆ 13.0   ┆ 11.952381 ┆ Marev4contig75_MelSat50-109_8478… │
# │ 4946  ┆ 14.0   ┆ 11.857143 ┆ Marev4contig75_MelSat50-109_8478… │
# │ 4947  ┆ 14.0   ┆ 11.809524 ┆ Marev4contig75_MelSat50-109_8478… │
# │ 4948  ┆ 15.0   ┆ 11.809524 ┆ Marev4contig75_MelSat50-109_8478… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (4_949, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 16.0   ┆ 12.142857 ┆ Marev4contig7_MelSat44-96_240089… │
# │ 1     ┆ 16.0   ┆ 12.142857 ┆ Marev4contig7_MelSat44-96_240089… │
# │ 2     ┆ 17.0   ┆ 12.142857 ┆ Marev4contig7_MelSat44-96_240089… │
# │ 3     ┆ 16.0   ┆ 12.142857 ┆ Marev4contig7_MelSat44-96_240089… │
# │ 4     ┆ 16.0   ┆ 12.142857 ┆ Marev4contig7_MelSat44-96_240089… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 4944  ┆ 13.0   ┆ 9.571429  ┆ Marev4contig7_MelSat44-96_240089… │
# │ 4945  ┆ 14.0   ┆ 9.619048  ┆ Marev4contig7_MelSat44-96_240089… │
# │ 4946  ┆ 14.0   ┆ 9.666667  ┆ Marev4contig7_MelSat44-96_240089… │
# │ 4947  ┆ 13.0   ┆ 9.666667  ┆ Marev4contig7_MelSat44-96_240089… │
# │ 4948  ┆ 13.0   ┆ 9.666667  ┆ Marev4contig7_MelSat44-96_240089… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (3_534, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 15.0   ┆ 10.380952 ┆ Marev4contig81_MelSat24-104_8584… │
# │ 1     ┆ 14.0   ┆ 10.333333 ┆ Marev4contig81_MelSat24-104_8584… │
# │ 2     ┆ 14.0   ┆ 10.238095 ┆ Marev4contig81_MelSat24-104_8584… │
# │ 3     ┆ 15.0   ┆ 10.190476 ┆ Marev4contig81_MelSat24-104_8584… │
# │ 4     ┆ 14.0   ┆ 10.142857 ┆ Marev4contig81_MelSat24-104_8584… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 3529  ┆ 0.0    ┆ 0.142857  ┆ Marev4contig81_MelSat24-104_8584… │
# │ 3530  ┆ 0.0    ┆ 0.190476  ┆ Marev4contig81_MelSat24-104_8584… │
# │ 3531  ┆ 0.0    ┆ 0.238095  ┆ Marev4contig81_MelSat24-104_8584… │
# │ 3532  ┆ 0.0    ┆ 0.285714  ┆ Marev4contig81_MelSat24-104_8584… │
# │ 3533  ┆ 0.0    ┆ 0.333333  ┆ Marev4contig81_MelSat24-104_8584… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (1_715, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 16.0   ┆ 11.380952 ┆ Marev4contig81_MelSat54-70_11852… │
# │ 1     ┆ 16.0   ┆ 11.333333 ┆ Marev4contig81_MelSat54-70_11852… │
# │ 2     ┆ 16.0   ┆ 11.333333 ┆ Marev4contig81_MelSat54-70_11852… │
# │ 3     ┆ 16.0   ┆ 11.380952 ┆ Marev4contig81_MelSat54-70_11852… │
# │ 4     ┆ 16.0   ┆ 11.428571 ┆ Marev4contig81_MelSat54-70_11852… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 1710  ┆ 11.0   ┆ 5.714286  ┆ Marev4contig81_MelSat54-70_11852… │
# │ 1711  ┆ 11.0   ┆ 5.761905  ┆ Marev4contig81_MelSat54-70_11852… │
# │ 1712  ┆ 10.0   ┆ 5.857143  ┆ Marev4contig81_MelSat54-70_11852… │
# │ 1713  ┆ 10.0   ┆ 5.952381  ┆ Marev4contig81_MelSat54-70_11852… │
# │ 1714  ┆ 10.0   ┆ 6.095238  ┆ Marev4contig81_MelSat54-70_11852… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (2_982, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 0.0    ┆ 0.0       ┆ Marev4contig82_MelSat76-170_1342… │
# │ 1     ┆ 0.0    ┆ 0.0       ┆ Marev4contig82_MelSat76-170_1342… │
# │ 2     ┆ 0.0    ┆ 0.0       ┆ Marev4contig82_MelSat76-170_1342… │
# │ 3     ┆ 0.0    ┆ 0.0       ┆ Marev4contig82_MelSat76-170_1342… │
# │ 4     ┆ 0.0    ┆ 0.0       ┆ Marev4contig82_MelSat76-170_1342… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 2977  ┆ 0.0    ┆ 0.619048  ┆ Marev4contig82_MelSat76-170_1342… │
# │ 2978  ┆ 0.0    ┆ 0.761905  ┆ Marev4contig82_MelSat76-170_1342… │
# │ 2979  ┆ 0.0    ┆ 0.952381  ┆ Marev4contig82_MelSat76-170_1342… │
# │ 2980  ┆ 0.0    ┆ 1.190476  ┆ Marev4contig82_MelSat76-170_1342… │
# │ 2981  ┆ 0.0    ┆ 1.428571  ┆ Marev4contig82_MelSat76-170_1342… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (1_814, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 14.0   ┆ 10.333333 ┆ Marev4contig86_MelSat19-175_1732… │
# │ 1     ┆ 14.0   ┆ 10.428571 ┆ Marev4contig86_MelSat19-175_1732… │
# │ 2     ┆ 14.0   ┆ 10.571429 ┆ Marev4contig86_MelSat19-175_1732… │
# │ 3     ┆ 14.0   ┆ 10.666667 ┆ Marev4contig86_MelSat19-175_1732… │
# │ 4     ┆ 13.0   ┆ 10.714286 ┆ Marev4contig86_MelSat19-175_1732… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 1809  ┆ 0.0    ┆ 0.0       ┆ Marev4contig86_MelSat19-175_1732… │
# │ 1810  ┆ 0.0    ┆ 0.0       ┆ Marev4contig86_MelSat19-175_1732… │
# │ 1811  ┆ 0.0    ┆ 0.0       ┆ Marev4contig86_MelSat19-175_1732… │
# │ 1812  ┆ 0.0    ┆ 0.0       ┆ Marev4contig86_MelSat19-175_1732… │
# │ 1813  ┆ 0.0    ┆ 0.0       ┆ Marev4contig86_MelSat19-175_1732… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (3_730, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 14.0   ┆ 10.47619  ┆ Marev4contig88_MelSat02-174_1770… │
# │ 1     ┆ 14.0   ┆ 10.47619  ┆ Marev4contig88_MelSat02-174_1770… │
# │ 2     ┆ 15.0   ┆ 10.47619  ┆ Marev4contig88_MelSat02-174_1770… │
# │ 3     ┆ 15.0   ┆ 10.428571 ┆ Marev4contig88_MelSat02-174_1770… │
# │ 4     ┆ 15.0   ┆ 10.428571 ┆ Marev4contig88_MelSat02-174_1770… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 3725  ┆ 18.0   ┆ 13.571429 ┆ Marev4contig88_MelSat02-174_1770… │
# │ 3726  ┆ 19.0   ┆ 13.47619  ┆ Marev4contig88_MelSat02-174_1770… │
# │ 3727  ┆ 19.0   ┆ 13.380952 ┆ Marev4contig88_MelSat02-174_1770… │
# │ 3728  ┆ 19.0   ┆ 13.333333 ┆ Marev4contig88_MelSat02-174_1770… │
# │ 3729  ┆ 19.0   ┆ 13.285714 ┆ Marev4contig88_MelSat02-174_1770… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (4_949, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 16.0   ┆ 10.761905 ┆ Marev4contig92_MelSat30-48_32384… │
# │ 1     ┆ 16.0   ┆ 10.619048 ┆ Marev4contig92_MelSat30-48_32384… │
# │ 2     ┆ 15.0   ┆ 10.52381  ┆ Marev4contig92_MelSat30-48_32384… │
# │ 3     ┆ 16.0   ┆ 10.428571 ┆ Marev4contig92_MelSat30-48_32384… │
# │ 4     ┆ 16.0   ┆ 10.333333 ┆ Marev4contig92_MelSat30-48_32384… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 4944  ┆ 18.0   ┆ 12.0      ┆ Marev4contig92_MelSat30-48_32384… │
# │ 4945  ┆ 19.0   ┆ 11.761905 ┆ Marev4contig92_MelSat30-48_32384… │
# │ 4946  ┆ 19.0   ┆ 11.571429 ┆ Marev4contig92_MelSat30-48_32384… │
# │ 4947  ┆ 19.0   ┆ 11.47619  ┆ Marev4contig92_MelSat30-48_32384… │
# │ 4948  ┆ 18.0   ┆ 11.428571 ┆ Marev4contig92_MelSat30-48_32384… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (4_949, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 13.0   ┆ 8.52381   ┆ Marev4contig93_MelSat08-134_2571… │
# │ 1     ┆ 13.0   ┆ 8.571429  ┆ Marev4contig93_MelSat08-134_2571… │
# │ 2     ┆ 13.0   ┆ 8.571429  ┆ Marev4contig93_MelSat08-134_2571… │
# │ 3     ┆ 12.0   ┆ 8.619048  ┆ Marev4contig93_MelSat08-134_2571… │
# │ 4     ┆ 12.0   ┆ 8.666667  ┆ Marev4contig93_MelSat08-134_2571… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 4944  ┆ 17.0   ┆ 12.666667 ┆ Marev4contig93_MelSat08-134_2571… │
# │ 4945  ┆ 17.0   ┆ 12.571429 ┆ Marev4contig93_MelSat08-134_2571… │
# │ 4946  ┆ 17.0   ┆ 12.52381  ┆ Marev4contig93_MelSat08-134_2571… │
# │ 4947  ┆ 18.0   ┆ 12.47619  ┆ Marev4contig93_MelSat08-134_2571… │
# │ 4948  ┆ 18.0   ┆ 12.380952 ┆ Marev4contig93_MelSat08-134_2571… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (1_300, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 3.0    ┆ 3.619048  ┆ Marev4contig93_MelSat28-54_27945… │
# │ 1     ┆ 3.0    ┆ 3.952381  ┆ Marev4contig93_MelSat28-54_27945… │
# │ 2     ┆ 3.0    ┆ 4.380952  ┆ Marev4contig93_MelSat28-54_27945… │
# │ 3     ┆ 3.0    ┆ 4.857143  ┆ Marev4contig93_MelSat28-54_27945… │
# │ 4     ┆ 3.0    ┆ 5.380952  ┆ Marev4contig93_MelSat28-54_27945… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 1295  ┆ 0.0    ┆ 0.52381   ┆ Marev4contig93_MelSat28-54_27945… │
# │ 1296  ┆ 0.0    ┆ 0.571429  ┆ Marev4contig93_MelSat28-54_27945… │
# │ 1297  ┆ 0.0    ┆ 0.666667  ┆ Marev4contig93_MelSat28-54_27945… │
# │ 1298  ┆ 0.0    ┆ 0.761905  ┆ Marev4contig93_MelSat28-54_27945… │
# │ 1299  ┆ 0.0    ┆ 0.904762  ┆ Marev4contig93_MelSat28-54_27945… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (1_993, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 18.0   ┆ 14.380952 ┆ Marev4contig96_MelSat14-95_10531… │
# │ 1     ┆ 18.0   ┆ 14.333333 ┆ Marev4contig96_MelSat14-95_10531… │
# │ 2     ┆ 19.0   ┆ 14.333333 ┆ Marev4contig96_MelSat14-95_10531… │
# │ 3     ┆ 19.0   ┆ 14.285714 ┆ Marev4contig96_MelSat14-95_10531… │
# │ 4     ┆ 19.0   ┆ 14.190476 ┆ Marev4contig96_MelSat14-95_10531… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 1988  ┆ 6.0    ┆ 7.428571  ┆ Marev4contig96_MelSat14-95_10531… │
# │ 1989  ┆ 6.0    ┆ 7.285714  ┆ Marev4contig96_MelSat14-95_10531… │
# │ 1990  ┆ 7.0    ┆ 7.095238  ┆ Marev4contig96_MelSat14-95_10531… │
# │ 1991  ┆ 8.0    ┆ 6.857143  ┆ Marev4contig96_MelSat14-95_10531… │
# │ 1992  ┆ 9.0    ┆ 6.571429  ┆ Marev4contig96_MelSat14-95_10531… │
# └───────┴────────┴───────────┴───────────────────────────────────┘
# shape: (4_949, 4)
# ┌───────┬────────┬───────────┬───────────────────────────────────┐
# │ index ┆ actual ┆ roll_mean ┆ name                              │
# │ ---   ┆ ---    ┆ ---       ┆ ---                               │
# │ i64   ┆ f64    ┆ f64       ┆ str                               │
# ╞═══════╪════════╪═══════════╪═══════════════════════════════════╡
# │ 0     ┆ 16.0   ┆ 12.47619  ┆ Marev4contig97_MelSat72-173_9221… │
# │ 1     ┆ 16.0   ┆ 12.52381  ┆ Marev4contig97_MelSat72-173_9221… │
# │ 2     ┆ 16.0   ┆ 12.52381  ┆ Marev4contig97_MelSat72-173_9221… │
# │ 3     ┆ 16.0   ┆ 12.52381  ┆ Marev4contig97_MelSat72-173_9221… │
# │ 4     ┆ 17.0   ┆ 12.571429 ┆ Marev4contig97_MelSat72-173_9221… │
# │ …     ┆ …      ┆ …         ┆ …                                 │
# │ 4944  ┆ 15.0   ┆ 12.714286 ┆ Marev4contig97_MelSat72-173_9221… │
# │ 4945  ┆ 16.0   ┆ 12.761905 ┆ Marev4contig97_MelSat72-173_9221… │
# │ 4946  ┆ 16.0   ┆ 12.809524 ┆ Marev4contig97_MelSat72-173_9221… │
# │ 4947  ┆ 16.0   ┆ 12.857143 ┆ Marev4contig97_MelSat72-173_9221… │
# │ 4948  ┆ 16.0   ┆ 12.904762 ┆ Marev4contig97_MelSat72-173_9221… │
# └───────┴────────┴───────────┴───────────────────────────────────┘

# %%
#find the min max values by unique array name in the filtered data
df_tot = pl.concat(df_list).filter(
    pl.col("roll_mean")<5.0
).group_by('name').agg(
    min_value=pl.col('index').min(),
    max_value=pl.col('index').max()
)

# %%
pl.concat(df_list).filter(
    pl.col("roll_mean")<5.0
).group_by('name').agg(
    min_value=pl.col('index').min(),
    max_value=pl.col('index').max()
)
# Out:
# shape: (60, 3)
# ┌───────────────────────────────────┬───────────┬───────────┐
# │ name                              ┆ min_value ┆ max_value │
# │ ---                               ┆ ---       ┆ ---       │
# │ str                               ┆ i64       ┆ i64       │
# ╞═══════════════════════════════════╪═══════════╪═══════════╡
# │ Marev4contig3_MelSat31-57_319552… ┆ 479       ┆ 4507      │
# │ Marev4contig97_MelSat72-173_9221… ┆ 421       ┆ 4540      │
# │ Marev4contig203_MelSat83-173_359… ┆ 350       ┆ 3417      │
# │ Marev4contig109_MelSat48-90_1034… ┆ 452       ┆ 4948      │
# │ Marev4contig24_MelSat78-97_23136… ┆ 454       ┆ 4465      │
# │ …                                 ┆ …         ┆ …         │
# │ Marev4contig109_MelSat22-186_395… ┆ 328       ┆ 4619      │
# │ Marev4contig3_MelSat73-76_393301… ┆ 423       ┆ 4453      │
# │ Marev4contig115_MelSat40-184_866… ┆ 328       ┆ 4543      │
# │ Marev4contig13_MelSat71-95_21773… ┆ 436       ┆ 4464      │
# │ Marev4contig122_MelSat79-78_8104… ┆ 410       ┆ 1398      │
# └───────────────────────────────────┴───────────┴───────────┘

# %%
df_tot = df_tot.with_columns(
    query = pl.col("name").map_elements(lambda x: x.split("_")[1])
)
df_tot =df_tot.rename({
        "min_value" : "start",
        "max_value" : "end",
        "query" : "feature",
        "name" : "seqnames"
    })

df_tot = df_tot.with_columns(
    [
        (pl.lit("feature")).alias("group"),
        (pl.lit("*")).alias("strand"),
        (pl.lit("EuSatXplor")).alias("source"),
        (pl.lit(".")).alias("frame"),
        (pl.lit("100")).alias("score")
    ]
)

# %%
df_tot
# Out:
# shape: (60, 9)
# ┌──────────────────────────┬───────┬──────┬──────────────┬───┬────────┬────────────┬───────┬───────┐
# │ seqnames                 ┆ start ┆ end  ┆ feature      ┆ … ┆ strand ┆ source     ┆ frame ┆ score │
# │ ---                      ┆ ---   ┆ ---  ┆ ---          ┆   ┆ ---    ┆ ---        ┆ ---   ┆ ---   │
# │ str                      ┆ i64   ┆ i64  ┆ str          ┆   ┆ str    ┆ str        ┆ str   ┆ str   │
# ╞══════════════════════════╪═══════╪══════╪══════════════╪═══╪════════╪════════════╪═══════╪═══════╡
# │ Marev4contig168_MelSat52 ┆ 436   ┆ 4948 ┆ MelSat52-97  ┆ … ┆ *      ┆ EuSatXplor ┆ .     ┆ 100   │
# │ -97_3786…                ┆       ┆      ┆              ┆   ┆        ┆            ┆       ┆       │
# │ Marev4contig7_MelSat44-9 ┆ 476   ┆ 4466 ┆ MelSat44-96  ┆ … ┆ *      ┆ EuSatXplor ┆ .     ┆ 100   │
# │ 6_240089…                ┆       ┆      ┆              ┆   ┆        ┆            ┆       ┆       │
# │ Marev4contig96_MelSat14- ┆ 437   ┆ 1976 ┆ MelSat14-95  ┆ … ┆ *      ┆ EuSatXplor ┆ .     ┆ 100   │
# │ 95_10531…                ┆       ┆      ┆              ┆   ┆        ┆            ┆       ┆       │
# │ Marev4contig60_MelSat67- ┆ 479   ┆ 4505 ┆ MelSat67-85  ┆ … ┆ *      ┆ EuSatXplor ┆ .     ┆ 100   │
# │ 85_16546…                ┆       ┆      ┆              ┆   ┆        ┆            ┆       ┆       │
# │ Marev4contig81_MelSat24- ┆ 69    ┆ 3533 ┆ MelSat24-104 ┆ … ┆ *      ┆ EuSatXplor ┆ .     ┆ 100   │
# │ 104_8584…                ┆       ┆      ┆              ┆   ┆        ┆            ┆       ┆       │
# │ …                        ┆ …     ┆ …    ┆ …            ┆ … ┆ …      ┆ …          ┆ …     ┆ …     │
# │ Marev4contig40_MelSat41- ┆ 364   ┆ 4948 ┆ MelSat41-175 ┆ … ┆ *      ┆ EuSatXplor ┆ .     ┆ 100   │
# │ 175_2369…                ┆       ┆      ┆              ┆   ┆        ┆            ┆       ┆       │
# │ Marev4contig92_MelSat30- ┆ 477   ┆ 4503 ┆ MelSat30-48  ┆ … ┆ *      ┆ EuSatXplor ┆ .     ┆ 100   │
# │ 48_32384…                ┆       ┆      ┆              ┆   ┆        ┆            ┆       ┆       │
# │ Marev4contig47_MelSat56- ┆ 445   ┆ 4501 ┆ MelSat56-62  ┆ … ┆ *      ┆ EuSatXplor ┆ .     ┆ 100   │
# │ 62_12664…                ┆       ┆      ┆              ┆   ┆        ┆            ┆       ┆       │
# │ Marev4contig13_MelSat25- ┆ 375   ┆ 2634 ┆ MelSat25-69  ┆ … ┆ *      ┆ EuSatXplor ┆ .     ┆ 100   │
# │ 69_72585…                ┆       ┆      ┆              ┆   ┆        ┆            ┆       ┆       │
# │ Marev4contig121_MelSat09 ┆ 372   ┆ 4948 ┆ MelSat09-94  ┆ … ┆ *      ┆ EuSatXplor ┆ .     ┆ 100   │
# │ -94_6794…                ┆       ┆      ┆              ┆   ┆        ┆            ┆       ┆       │
# └──────────────────────────┴───────┴──────┴──────────────┴───┴────────┴────────────┴───────┴───────┘

# %%
df_tot = df_tot.select(
                ["seqnames","source","feature","start","end","score","strand","frame","group"]
    )



#read in the original arrays
df = read_gff_output("../results/data/tables/arrays.gff",headers=False)

df_real_edges = df_tot
if constants.SQUISH:
    df = df.with_columns(
        name = pl.col("seqnames")+"_" + pl.col("group") +"_" + pl.col("start").cast(pl.String)+"_" + pl.col("end").cast(pl.String)
    ).with_columns(
        len= pl.col("end") -pl.col("start")
    )


    df = df.join(df_real_edges,left_on="name",right_on="seqnames")

    df = df.with_columns(
        real_start=pl.col("start") - (500-pl.col("start_right"))).with_columns(
        real_end=pl.when(pl.col("len")<5000)
                    .then(pl.col("end_right") - pl.col("start_right") + pl.col("real_start")) 
                    .otherwise(pl.col("end") + (5000-pl.col("end_right")))
    ).select(
            ["seqnames","source","feature","real_start","real_end","score","strand","frame","group"]
    ).rename(
        {
            "real_start" : "start",
            "real_end" :"end"
        }
    )
    
    
    extract_array_flanks(df=df,fasta_records=fasta_records)

    extract_array_flanks(df=df,fasta_records=fasta_records,
                        flank_size=20,flank_type="microhomology")
# Out:
# shape: (60, 9)
# ┌────────────────┬────────────┬──────────────┬─────────┬───┬───────┬────────┬───────┬──────────────┐
# │ seqnames       ┆ source     ┆ feature      ┆ start   ┆ … ┆ score ┆ strand ┆ frame ┆ group        │
# │ ---            ┆ ---        ┆ ---          ┆ ---     ┆   ┆ ---   ┆ ---    ┆ ---   ┆ ---          │
# │ str            ┆ str        ┆ str          ┆ i64     ┆   ┆ i64   ┆ str    ┆ str   ┆ str          │
# ╞════════════════╪════════════╪══════════════╪═════════╪═══╪═══════╪════════╪═══════╪══════════════╡
# │ Marev4contig10 ┆ EuSatXplor ┆ MelSat10-63  ┆ 3177183 ┆ … ┆ 100   ┆ -      ┆ .     ┆ MelSat10-63  │
# │ Marev4contig3  ┆ EuSatXplor ┆ MelSat21-55  ┆ 3821227 ┆ … ┆ 100   ┆ -      ┆ .     ┆ MelSat21-55  │
# │ Marev4contig3  ┆ EuSatXplor ┆ MelSat33-57  ┆ 3467635 ┆ … ┆ 100   ┆ +      ┆ .     ┆ MelSat33-57  │
# │ Marev4contig13 ┆ EuSatXplor ┆ MelSat74-97  ┆ 566370  ┆ … ┆ 100   ┆ +      ┆ .     ┆ MelSat74-97  │
# │ 7              ┆            ┆              ┆         ┆   ┆       ┆        ┆       ┆              │
# │ Marev4contig10 ┆ EuSatXplor ┆ MelSat16-76  ┆ 3700660 ┆ … ┆ 100   ┆ +      ┆ .     ┆ MelSat16-76  │
# │ …              ┆ …          ┆ …            ┆ …       ┆ … ┆ …     ┆ …      ┆ …     ┆ …            │
# │ Marev4contig97 ┆ EuSatXplor ┆ MelSat72-173 ┆ 922085  ┆ … ┆ 100   ┆ +      ┆ .     ┆ MelSat72-173 │
# │ Marev4contig47 ┆ EuSatXplor ┆ MelSat56-62  ┆ 1266351 ┆ … ┆ 100   ┆ +      ┆ .     ┆ MelSat56-62  │
# │ Marev4contig40 ┆ EuSatXplor ┆ MelSat41-175 ┆ 2369064 ┆ … ┆ 100   ┆ +      ┆ .     ┆ MelSat41-175 │
# │ Marev4contig10 ┆ EuSatXplor ┆ MelSat49-103 ┆ 23992   ┆ … ┆ 100   ┆ -      ┆ .     ┆ MelSat49-103 │
# │ 5              ┆            ┆              ┆         ┆   ┆       ┆        ┆       ┆              │
# │ Marev4contig2  ┆ EuSatXplor ┆ MelSat47-240 ┆ 3855392 ┆ … ┆ 100   ┆ +      ┆ .     ┆ MelSat47-240 │
# └────────────────┴────────────┴──────────────┴─────────┴───┴───────┴────────┴───────┴──────────────┘
